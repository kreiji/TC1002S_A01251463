# %%
# Importar librerías a utilizar 
import numpy as np
import matplotlib.pyplot as plt 

import pandas as pd  
import seaborn as sns

# %%
# Carga del conjunto de datos de precios de casas de Boston
# de la librería sklearn
pol = pd.read_csv('Pace_of_life.csv', na_values = ':',
                   usecols = ["City","Walk","Bank","Talk","Heart"])
pol
# Out:
#               City  Walk  Bank  Talk  Heart
# 0           Boston    28    31    24     24
# 1          Buffalo    23    30    23     29
# 2         New York    24    29    18     31
# 3   Salt Lake City    28    28    23     26
# 4         Columbus    22    27    30     26
# 5        Worcester    25    26    24     20
# 6       Providence    26    30    24     17
# 7      Springfield    30    28    21     19
# 8        Rochester    22    33    18     26
# 9      Kansas City    22    33    22     24
# 10        St Louis    23    22    23     26
# 11         Houston    25    30    20     25
# 12        Paterson    23    32    23     14
# 13     Bakersfield    18    29    25     11
# 14         Atlanta    27    25    27     19
# 15         Detroit    22    24    14     24
# 16      Youngstown    23    27    24     20
# 17    Indianapolis    22    26    24     13
# 18         Chicago    23    24    25     20
# 19    Philadelphia    12    31    19     18
# ...

# %%
# Convertir el data set en DataFrame
import pandas as pd
df = pd.DataFrame(pol)
df.head()
# Out:
#              City  Walk  Bank  Talk  Heart
# 0          Boston    28    31    24     24
# 1         Buffalo    23    30    23     29
# 2        New York    24    29    18     31
# 3  Salt Lake City    28    28    23     26
# 4        Columbus    22    27    30     26

# %%
# Verificar si hay datos perdidos
df.isnull().sum()
# Out:
# City     0
# Walk     0
# Bank     0
# Talk     0
# Heart    0
# dtype: int64

# %%
# Se utiliza displot de la librería seaborn para
# un crear el histograma
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(pol['Heart'], bins=30)
plt.show() 

sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(pol['Talk'], bins=30)
plt.show() 

sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(pol['Walk'], bins=30)
plt.show() 

sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(pol['Bank'], bins=30)
plt.show()
# Out:
# /home/careliaiv/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/careliaiv/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Se obtiene una matriz de correlación
correlation_matrix = pol.corr().round(2)
# Se usa la matriz de correlación para dibujar un mapa de calor
# annot = True para mostrar los valores dentro del cuadro
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
# Conjunto de varias series de datos para crear un boxplot
datos = [pol["Walk"].values, pol["Bank"].values, pol["Talk"].values, pol["Heart"].values]
fig = plt.figure(figsize=(10,7))
bp = plt.boxplot(datos)
plt.show()
